# %%
#nltk book improt
import nltk
from nltk.book import *
nltk.download('book', quiet=True)
# Out:
# True

# %%
from nltk import book

# %% [markdown]
# ## 1. text5에서 4번 출현하는 단어들을 중복되지 않게 오름차순으로 출력하시오

# %%
#FreqDist()이용!
#리스트컴프리헨션 이용!

fdist = FreqDist(text5)
[word for word in sorted(set(text5.tokens)) if text5.count(word) == 4]
# Out:
# ["''",
#  '(((',
#  '((((((((',
#  '(((((((((',
#  '))))))))))',
#  ',,,,',
#  '..........',
#  '10',
#  '15',
#  '23',
#  '8',
#  '80',
#  ':-(',
#  ':-@',
#  ':O',
#  ':beer:',
#  ':p',
#  '<<',
#  'Any',
#  'Dawnstar',
#  'EST',
#  'Everyone',
#  'Florida',
#  'Go',
#  'Kittie',
#  'Like',
#  'MY',
#  'Messaging',
#  'N',
#  'ONE',
#  'Ok',
#  'Private',
#  'ROOM',
#  'S',
#  'South',
#  'To',
#  'U',
#  'U117',
#  'U123',
#  'U126',
#  'U130',
#  'U133',
#  'U146',
#  'U154',
#  'U196',
#  'U219',
#  'U819',
#  'U820',
#  'U85',
#  'U88',
#  'U988',
#  'U989',
#  'Visit',
#  'We',
#  'Wellbutrin',
#  'White',
#  'Wow',
#  'afternoon',
#  'ahh',
#  'alright',
#  'asses',
#  'barbie',
#  'beat',
#  'behind',
#  'between',
#  'bitch',
#  'blank',
#  'box',
#  'bring',
#  'c',
#  'calling',
#  'caught',
#  'charge',
#  'cheap',
#  'choice',
#  'claws',
#  'com',
#  'country',
#  'cup',
#  'cute',
#  'dam',
#  'dances',
#  'darlin',
#  'date',
#  'dating',
#  'daughter',
# ...

# %% [markdown]
# ## 4.text4에서 4자리 단어만 출력하기

# %%
#리스트컴프리헨션을 이용!

[word for word in sorted(set(text4.tokens)) if len(word) == 4 and word.isalpha()]
# Out:
# ['AIDS',
#  'Amen',
#  'Amid',
#  'Army',
#  'Asia',
#  'Bell',
#  'Bill',
#  'Both',
#  'Bush',
#  'Cape',
#  'Care',
#  'Chop',
#  'Clay',
#  'Code',
#  'Cold',
#  'Cook',
#  'Cuba',
#  'Dark',
#  'Does',
#  'Dole',
#  'Each',
#  'East',
#  'Envy',
#  'Even',
#  'Ever',
#  'FROM',
#  'Fort',
#  'Four',
#  'From',
#  'Gaul',
#  'Give',
#  'Good',
#  'Gore',
#  'Gulf',
#  'Half',
#  'Hall',
#  'Hand',
#  'Hard',
#  'Have',
#  'Hear',
#  'Help',
#  'Here',
#  'High',
#  'Hill',
#  'Holy',
#  'Hope',
#  'Horn',
#  'Idle',
#  'Indo',
#  'Iowa',
#  'Iraq',
#  'Jews',
#  'Jima',
#  'John',
#  'July',
#  'Just',
#  'King',
#  'Lady',
#  'Laws',
#  'Less',
#  'Like',
#  'Long',
#  'Look',
#  'Lord',
#  'Love',
#  'Make',
#  'Mall',
#  'Many',
#  'Mars',
#  'Mill',
#  'Mind',
#  'Miss',
#  'Moon',
#  'More',
#  'Most',
#  'Much',
#  'Must',
#  'Navy',
#  'Next',
#  'None',
#  'Ohio',
#  'Once',
#  'Only',
#  'Ours',
#  'Over',
#  'Page',
#  'Pool',
#  'Pork',
#  'Race',
#  'Rico',
# ...

# %% [markdown]
# ## 6. 아래의 지문을 똑같이 출력하는 프로그램을 작성하시오. (한 줄에 한 문장씩 출력, 문자열 간격과 줄바꿈에 유의하여 작성)
#
# - 과목명: 고급 파이썬 프로그래밍\Advanced Python programming
#     - "이 수업은 금요일에 진행됩니다."
#
# - 수업은 실시간 강의로 진행됩니다.
#     - 질의사항은 조교에게 메일로 보내주세요

# %%
print("""
        과목명 : 고급파이썬 프로그래밍/Advanced Python programming \n
        \t\"이 수업은 금요일에 진행됩니다.\"\n
        \n
        수업은 실시간 강의로 진행됩니다.\n
        \t-질의사항은 조교에게 메일로 보내주세요
    """)
# Out:
#         과목명 : 고급파이썬 프로그래밍/Advanced Python programming
#
#         	"이 수업은 금요일에 진행됩니다."
#
#
#
#         수업은 실시간 강의로 진행됩니다.
#
#         	-질의사항은 조교에게 메일로 보내주세요
